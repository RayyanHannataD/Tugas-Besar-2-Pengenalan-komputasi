# %% [markdown]
# ## **Tugas Besar 2 Pengenalan Komputasi**
# ### **Kelompok 6**
# - Ester Tri Wahyuningsih (16022101)
# - Rayyan Hannata Denan   (16022106)
# - Valentinus Brian Johan (16022111)
# - Brian Matthew          (16022116)

# %% [markdown]
# ### Import modul-modul yang dibutuhkan dari library

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ### File 'supermarket_sales - Sheet1.csv' dimasukkan ke variabel bernama df menggunakan library pandas

# %%
df = pd.read_csv('supermarket_sales - Sheet1.csv')

# %% [markdown]
# ### Menampilkan dataframe

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## Kolom 1 **'Invoice ID'**
# ### Invoice ID merupakan *computer-generated number* yang digunakan untuk mengidentifikasi sebuah transaksi

# %% [markdown]
# ### Khusus untuk data ini, invoice ID tidak memuat suatu pola tertentu (contoh: 3 angka pertama berisi kode cabang dan lokasi, 2 angka ditengah berisi kode barang yang dibeli)
# ### Berikut sampel data invoice ID dengan **3 angka pertama yang sama**

# %%
id = df['Invoice ID'].str.contains('101-', case=False, na = False )
df[id]
# Berikut data Invoice ID yang memuat nomor '803' sebagai 3 angka pertama
# Out:
#       Invoice ID Branch       City Customer type  Gender        Product line  \
# 162  101-17-6199      A     Yangon        Normal    Male  Food and beverages
# 867  101-81-4070      C  Naypyitaw        Member  Female   Health and beauty
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 162       45.79         7  16.0265  336.5565  3/13/2019  19:44  Credit card
# 867       62.82         2   6.2820  131.9220  1/17/2019  12:36      Ewallet
#
#        cogs  gross margin percentage  gross income  Rating
# 162  320.53                 4.761905       16.0265     7.0
# 867  125.64                 4.761905        6.2820     4.9

# %% [markdown]
# ### Berikut sampel data invoice ID dengan **2 angka tengah yang sama**

# %%
id2 = df['Invoice ID'].str.contains('-01-', case=False, na = False )
df[id2]
# Berikut data Invoice ID yang memuat nomor '803' sebagai 3 angka pertama
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 79   756-01-7507      C  Naypyitaw        Normal  Female
# 99   733-01-9107      B   Mandalay        Normal    Male
# 108  588-01-7461      C  Naypyitaw        Normal  Female
# 114  237-01-6122      C  Naypyitaw        Member  Female
# 198  699-01-4164      C  Naypyitaw        Normal    Male
# 221  468-01-2051      B   Mandalay        Normal    Male
# 306  286-01-5402      A     Yangon        Normal  Female
# 376  843-01-4703      B   Mandalay        Member  Female
# 396  316-01-3952      A     Yangon        Normal  Female
# 450  891-01-7034      B   Mandalay        Normal  Female
# 485  438-01-4015      B   Mandalay        Member  Female
# 524  534-01-4457      A     Yangon        Normal    Male
# 693  196-01-2849      C  Naypyitaw        Member  Female
# 909  624-01-8356      B   Mandalay        Normal  Female
# 993  690-01-6631      B   Mandalay        Normal    Male
#
# ...

# %% [markdown]
# ## Kolom 2 **'Branch'**

# %% [markdown]
# ### Kolom **'Branch'** berisi data mengenai kode kota tempat transaksi dilakukan

# %% [markdown]
# ### Terdapat 3 kode kota yaitu **A**, **B**, dan **C** dengan jumlah transaksi di tiap-tiap branch :

# %%
pd.DataFrame(df['Branch'].value_counts())
# Jumlah data yang telah disortir berdasarkan 'Branch'
# Out:
#    Branch
# A     340
# B     332
# C     328

# %% [markdown]
# ## Kolom 3 **'City'**

# %% [markdown]
# ### Kolom **'City'** berisi data mengenai kota tempat transaksi dilakukan

# %% [markdown]
# ### Terdapat 3 kode kota yaitu **Yangon**, **Mandalay**, dan **Naypyitaw** dengan jumlah transaksi di tiap-tiap kota :

# %%
pd.DataFrame(df['City'].value_counts())
# Jumlah data yang telah disortir berdasarkan 'City'
# Out:
#            City
# Yangon      340
# Mandalay    332
# Naypyitaw   328

# %% [markdown]
# ## Kolom 4 **'Customer type'**

# %% [markdown]
# ### Kolom **'Customer Type'** berisi data jenis membership pelanggan

# %% [markdown]
# ### Terdapat 2 *customer type* yaitu *member* dan *normal* dengan jumlah masing-masing :

# %%
pd.DataFrame(df['Customer type'].value_counts())
# Out:
#         Customer type
# Member            501
# Normal            499

# %% [markdown]
# ## Kolom 5 **'Gender'**

# %% [markdown]
# ### Kolom **'Gender'** berisi data jenis kelamin pelanggan

# %% [markdown]
# ### Terdapat 2 jenis kelamin yaitu *male* dan *female* dengan jumlah masing-masing :

# %%
pd.DataFrame(df['Gender'].value_counts())
# Out:
#         Gender
# Female     501
# Male       499

# %% [markdown]
# ## Kolom 6 **'Product line'**

# %% [markdown]
# ### Kolom **'Product line'** berisi data jenis barang yang dibeli pelanggan

# %% [markdown]
# ### Terdapat 6 *product line* dengan jumlah masing-masing :

# %%
PL = pd.DataFrame(df['Product line'].value_counts())
PL
# Out:
#                         Product line
# Fashion accessories              178
# Food and beverages               174
# Electronic accessories           170
# Sports and travel                166
# Home and lifestyle               160
# Health and beauty                152

# %% [markdown]
# ### Berikut *product line* yang paling banyak dibeli :

# %%
max_p = PL['Product line'].max()
PL.loc[PL['Product line'] == max_p]
# Out:
#                      Product line
# Fashion accessories           178

# %% [markdown]
# ### Berikut *product line* yang paling sedikit dibeli :

# %%
min_p = PL['Product line'].min()
PL.loc[PL['Product line'] == min_p]
# Out:
#                    Product line
# Health and beauty           152

# %% [markdown]
# ## Kolom 7 **'Unit price'**

# %% [markdown]
# ### Kolom **'Unit price'** berisi data harga barang yang dibeli

# %% [markdown]
# ### Berikut transaksi dengan *Unit price* tertinggi

# %%
max_U = df['Unit price'].max()
df.loc[df['Unit price'] == max_U]
# Out:
#       Invoice ID Branch       City Customer type Gender       Product line  \
# 122  219-22-9386      B   Mandalay        Member   Male  Sports and travel
# 983  148-41-7930      C  Naypyitaw        Normal   Male  Health and beauty
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 122       99.96         9  44.982  944.622   3/9/2019  17:26  Credit card
# 983       99.96         7  34.986  734.706  1/23/2019  10:33         Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 122  899.64                 4.761905        44.982     4.2
# 983  699.72                 4.761905        34.986     6.1

# %% [markdown]
# ### Berikut transaksi dengan *Unit price* terendah

# %%
min_U = df['Unit price'].min()
df.loc[df['Unit price'] == min_U]
# Out:
#       Invoice ID Branch    City Customer type Gender       Product line  \
# 944  333-23-2632      A  Yangon        Member   Male  Health and beauty
#
#      Unit price  Quantity  Tax 5%   Total       Date   Time Payment   cogs  \
# 944       10.08         7   3.528  74.088  3/28/2019  20:14    Cash  70.56
#
#      gross margin percentage  gross income  Rating
# 944                 4.761905         3.528     4.2

# %% [markdown]
# ## Kolom 8 **'Quantity'**

# %% [markdown]
# ### Kolom **'Quantity'** berisi data jumlah barang yang dibeli tiap transaksi

# %%
max_q = df['Quantity'].max()
print('Jumlah barang terbanyak yang pernah dibeli dalam satu transaksi adalah', max_q, 'barang')
# Out:
# Jumlah barang terbanyak yang pernah dibeli dalam satu transaksi adalah 10 barang

# %%
min_q = df['Quantity'].min()
print('Jumlah barang paling sedikit yang pernah dibeli dalam satu transaksi adalah', min_q, 'barang')
# Out:
# Jumlah barang paling sedikit yang pernah dibeli dalam satu transaksi adalah 1 barang

# %% [markdown]
# ### Berikut jumlah transaksi dari tiap-tiap *Quantity* :

# %%
pd.DataFrame(df['Quantity'].value_counts())
# Out:
#     Quantity
# 10       119
# 1        112
# 4        109
# 7        102
# 5        102
# 6         98
# 9         92
# 2         91
# 3         90
# 8         85

# %% [markdown]
# ## Kolom 9 **'Tax 5%'**

# %% [markdown]
# ### Kolom **'Tax 5%'** berisi data jumlah pajak yang diberikan untuk suatu transaksi

# %% [markdown]
# ### Berikut transaksi dengan jumlah pajak terbesar :

# %%
df.nlargest(1, columns='Tax 5%').loc[:,['Invoice ID', 'Unit price', 'Quantity', 'Tax 5%', 'Total']]
# Out:
#       Invoice ID  Unit price  Quantity  Tax 5%    Total
# 350  860-79-0874        99.3        10   49.65  1042.65

# %% [markdown]
# ### Berikut transaksi dengan jumlah pajak paling sedikit :

# %%
df.nsmallest(1, columns='Tax 5%').loc[:,['Invoice ID', 'Unit price', 'Quantity', 'Tax 5%', 'Total']]
# Out:
#       Invoice ID  Unit price  Quantity  Tax 5%    Total
# 822  784-21-9238       10.17         1  0.5085  10.6785

# %% [markdown]
# ## Kolom 10 **'Total'**

# %% [markdown]
# ### Kolom 'Total' berisi data jumlah yang harus dibayarkan pada suatu transaksi

# %% [markdown]
# ### nilai *Total* dapat dicari menggunakan rumus :
# $
# Total = [Quantity * Unit price] + \frac{5}{100} [Quantity * Unit price]
# $

# %% [markdown]
# ### Berikut transaksi dengan total pembayaran terbesar :

# %%
df.nlargest(1, columns='Total').loc[:,['Invoice ID', 'Unit price', 'Quantity', 'Tax 5%', 'Total']]
# Out:
#       Invoice ID  Unit price  Quantity  Tax 5%    Total
# 350  860-79-0874        99.3        10   49.65  1042.65

# %% [markdown]
# ### Berikut transaksi dengan total pembayaran paling sedikit :

# %%
df.nsmallest(1, columns='Total').loc[:,['Invoice ID', 'Unit price', 'Quantity', 'Tax 5%', 'Total']]
# Out:
#       Invoice ID  Unit price  Quantity  Tax 5%    Total
# 822  784-21-9238       10.17         1  0.5085  10.6785

# %% [markdown]
# ## Kolom 11 **'Date'**

# %% [markdown]
# ### Kolom 'Date' berisi data tanggal terjadinya transaksi

# %% [markdown]
# ### Berikut data jumlah transaksi tiap bulan dari Januari sampai maret

# %%
df['Date'] = pd.to_datetime(df['Date'])
Tot_Jan = len(df.loc[df['Date'] < '2/1/2019'])
Tot_Feb = len(df.loc[(df['Date'] > '1/31/2019') & (df['Date'] < '3/1/2019')])
Tot_Mar = len(df.loc[(df['Date'] > '2/28/2019') & (df['Date'] < '3/31/2019')])
T_perbulan = {}
T_perbulan['Month'] = ['January', 'February', 'March']
T_perbulan['Transactions'] = [Tot_Jan,Tot_Feb, Tot_Mar]
dfd = pd.DataFrame(data=T_perbulan)
dfd
# Out:
#       Month  Transactions
# 0   January           352
# 1  February           303
# 2     March           345

# %% [markdown]
# ### Berikut bulan dengan transaksi terbanyak

# %%
dfd.nlargest(1, columns= 'Transactions')
# Out:
#      Month  Transactions
# 0  January           352

# %% [markdown]
# ### Berikut bulan dengan transaksi paling sedikit

# %%
dfd.nsmallest(1, columns= 'Transactions')
# Out:
#       Month  Transactions
# 1  February           303

# %% [markdown]
# ## Kolom 12 **'Time'**

# %%
df.sort_values(by='Time')
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 913  522-57-8364      A     Yangon        Member    Male
# 180  130-98-8941      C  Naypyitaw        Normal    Male
# 293  316-68-6352      A     Yangon        Member  Female
# 200  606-80-4905      C  Naypyitaw        Member  Female
# 669  679-22-6530      B   Mandalay        Normal  Female
# ..           ...    ...        ...           ...     ...
# 106  628-34-3388      C  Naypyitaw        Normal    Male
# 267  571-94-0759      B   Mandalay        Member  Female
# 893  715-20-1673      B   Mandalay        Normal    Male
# 136  700-81-1757      A     Yangon        Normal  Female
# 935  235-06-8510      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 913     Fashion accessories       51.34         8  20.5360  431.2560
# 180     Fashion accessories       64.26         7  22.4910  472.3110
# 293      Food and beverages       36.36         2   3.6360   76.3560
# ...

# %%
df.loc[(df['Time'] >= '10') & (df['Time'] < '12' )]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 4    373-73-7910      A     Yangon        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 12   365-64-0515      A     Yangon        Normal  Female
# 16   656-95-9349      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 975  883-69-1285      B   Mandalay        Member    Male
# 976  221-25-5073      A     Yangon        Normal  Female
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 4         Sports and travel       86.31         7  30.2085  634.3785
# 7        Home and lifestyle       73.56        10  36.7800  772.3800
# ...
